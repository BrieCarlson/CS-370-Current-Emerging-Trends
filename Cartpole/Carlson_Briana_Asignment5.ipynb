# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 15
# Scores: (min: 15, avg: 15, max: 15)
#
# Run: 2, exploration: 0.9229311239742362, score: 21
# Scores: (min: 15, avg: 18, max: 21)
#
# Run: 3, exploration: 0.7705488893118823, score: 37
# Scores: (min: 15, avg: 24.333333333333332, max: 37)
#
# Run: 4, exploration: 0.7076077347272662, score: 18
# Scores: (min: 15, avg: 22.75, max: 37)
#
# Run: 5, exploration: 0.6662995813682115, score: 13
# Scores: (min: 13, avg: 20.8, max: 37)
#
# Run: 6, exploration: 0.6180388156137953, score: 16
# Scores: (min: 13, avg: 20, max: 37)
#
# Run: 7, exploration: 0.5907768628656763, score: 10
# Scores: (min: 10, avg: 18.571428571428573, max: 37)
#
# Run: 8, exploration: 0.5647174463480732, score: 10
# Scores: (min: 10, avg: 17.5, max: 37)
#
# Run: 9, exploration: 0.531750826943791, score: 13
# Scores: (min: 10, avg: 17, max: 37)
#
# Run: 10, exploration: 0.4858739637363176, score: 19
# Scores: (min: 10, avg: 17.2, max: 37)
#
# Run: 11, exploration: 0.46677573701590436, score: 9
# Scores: (min: 9, avg: 16.454545454545453, max: 37)
#
# Run: 12, exploration: 0.4439551321314536, score: 11
# Scores: (min: 9, avg: 16, max: 37)
#
# Run: 13, exploration: 0.4222502236424958, score: 11
# Scores: (min: 9, avg: 15.615384615384615, max: 37)
#
# Run: 14, exploration: 0.39561243860243744, score: 14
# Scores: (min: 9, avg: 15.5, max: 37)
#
# Run: 15, exploration: 0.3800621177172763, score: 9
# Scores: (min: 9, avg: 15.066666666666666, max: 37)
#
# Run: 16, exploration: 0.3632974174544486, score: 10
# Scores: (min: 9, avg: 14.75, max: 37)
#
# Run: 17, exploration: 0.3472722151889232, score: 10
# Scores: (min: 9, avg: 14.470588235294118, max: 37)
#
# Run: 18, exploration: 0.3302941218954743, score: 11
# Scores: (min: 9, avg: 14.277777777777779, max: 37)
#
# Run: 19, exploration: 0.31101247816653554, score: 13
# Scores: (min: 9, avg: 14.210526315789474, max: 37)
#
# Run: 20, exploration: 0.2943280830920294, score: 12
# Scores: (min: 9, avg: 14.1, max: 37)
#
# Run: 21, exploration: 0.28134514724562876, score: 10
# Scores: (min: 9, avg: 13.904761904761905, max: 37)
#
# Run: 22, exploration: 0.2702863258025825, score: 9
# Scores: (min: 9, avg: 13.681818181818182, max: 37)
#
# Run: 23, exploration: 0.25966219297210513, score: 9
# Scores: (min: 9, avg: 13.478260869565217, max: 37)
#
# Run: 24, exploration: 0.24328132378095624, score: 14
# Scores: (min: 9, avg: 13.5, max: 37)
#
# Run: 25, exploration: 0.23371867538818816, score: 9
# Scores: (min: 9, avg: 13.32, max: 37)
#
# Run: 26, exploration: 0.22007483514733558, score: 13
# Scores: (min: 9, avg: 13.307692307692308, max: 37)
#
# Run: 27, exploration: 0.21142436319205632, score: 9
# Scores: (min: 9, avg: 13.148148148148149, max: 37)
#
# Run: 28, exploration: 0.20209834538617025, score: 10
# Scores: (min: 9, avg: 13.035714285714286, max: 37)
#
# Run: 29, exploration: 0.18373897616330553, score: 20
# Scores: (min: 9, avg: 13.275862068965518, max: 37)
#
# Run: 30, exploration: 0.17651675623376062, score: 9
# Scores: (min: 9, avg: 13.133333333333333, max: 37)
#
# Run: 31, exploration: 0.17043057265153258, score: 8
# Scores: (min: 8, avg: 12.96774193548387, max: 37)
#
# Run: 32, exploration: 0.16209824418995536, score: 11
# Scores: (min: 8, avg: 12.90625, max: 37)
#
# Run: 33, exploration: 0.1549480222912372, score: 10
# Scores: (min: 8, avg: 12.818181818181818, max: 37)
#
# Run: 34, exploration: 0.14811319969530845, score: 10
# Scores: (min: 8, avg: 12.735294117647058, max: 37)
#
# Run: 35, exploration: 0.14229132060898236, score: 9
# Scores: (min: 8, avg: 12.628571428571428, max: 37)
#
# Run: 36, exploration: 0.13738520790976036, score: 8
# Scores: (min: 8, avg: 12.5, max: 37)
#
# Run: 37, exploration: 0.12936504510050365, score: 13
# Scores: (min: 8, avg: 12.513513513513514, max: 37)
#
# Run: 38, exploration: 0.11130363979080501, score: 31
# Scores: (min: 8, avg: 13, max: 37)
#
# Run: 39, exploration: 0.10119240105273684, score: 20
# Scores: (min: 8, avg: 13.179487179487179, max: 37)
#
# Run: 40, exploration: 0.09528507271768329, score: 13
# Scores: (min: 8, avg: 13.175, max: 37)
#
# Run: 41, exploration: 0.08750185146499175, score: 18
# Scores: (min: 8, avg: 13.292682926829269, max: 37)
#
# Run: 42, exploration: 0.07719590465791494, score: 26
# Scores: (min: 8, avg: 13.595238095238095, max: 37)
#
# Run: 43, exploration: 0.06810378976195819, score: 26
# Scores: (min: 8, avg: 13.883720930232558, max: 37)
#
# Run: 44, exploration: 0.06285510723190912, score: 17
# Scores: (min: 8, avg: 13.954545454545455, max: 37)
#
# Run: 45, exploration: 0.05772088009124167, score: 18
# Scores: (min: 8, avg: 14.044444444444444, max: 37)
#
# Run: 46, exploration: 0.04470026135116646, score: 52
# Scores: (min: 8, avg: 14.869565217391305, max: 52)
#
# Run: 47, exploration: 0.0386526615487428, score: 30
# Scores: (min: 8, avg: 15.191489361702128, max: 52)
#
# Run: 48, exploration: 0.03549537564593805, score: 18
# Scores: (min: 8, avg: 15.25, max: 52)
#
# Run: 49, exploration: 0.028756840457888354, score: 43
# Scores: (min: 8, avg: 15.816326530612244, max: 52)
#
# Run: 50, exploration: 0.023181078627322618, score: 44
# Scores: (min: 8, avg: 16.38, max: 52)
#
# Run: 51, exploration: 0.020145585821044927, score: 29
# Scores: (min: 8, avg: 16.627450980392158, max: 52)
#
# Run: 52, exploration: 0.01575835418494799, score: 50
# Scores: (min: 8, avg: 17.26923076923077, max: 52)
#
# Run: 53, exploration: 0.013156542237201536, score: 37
# Scores: (min: 8, avg: 17.641509433962263, max: 52)
#
# Run: 54, exploration: 0.010137759008060509, score: 53
# Scores: (min: 8, avg: 18.296296296296298, max: 53)
#
# Run: 55, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 18.4, max: 53)
#
# Run: 56, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 18.660714285714285, max: 53)
#
# Run: 57, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 19.087719298245613, max: 53)
#
# Run: 58, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 19.24137931034483, max: 53)
#
# Run: 59, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 19.88135593220339, max: 57)
#
# Run: 60, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 19.916666666666668, max: 57)
#
# Run: 61, exploration: 0.01, score: 126
# Scores: (min: 8, avg: 21.65573770491803, max: 126)
#
# Run: 62, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 21.596774193548388, max: 126)
#
# Run: 63, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 22.19047619047619, max: 126)
#
# Run: 64, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 22.34375, max: 126)
#
# Run: 65, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 22.953846153846154, max: 126)
#
# Run: 66, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 23.257575757575758, max: 126)
#
# Run: 67, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 23.791044776119403, max: 126)
#
# Run: 68, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 24.102941176470587, max: 126)
#
# Run: 69, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 24.231884057971016, max: 126)
#
# Run: 70, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 24.357142857142858, max: 126)
#
# Run: 71, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 25.492957746478872, max: 126)
#
# Run: 72, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 25.63888888888889, max: 126)
#
# Run: 73, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 26.34246575342466, max: 126)
#
# Run: 74, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 27.33783783783784, max: 126)
#
# Run: 75, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 28.52, max: 126)
#
# Run: 76, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 29.460526315789473, max: 126)
#
# Run: 77, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 29.92207792207792, max: 126)
#
# Run: 78, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 30.935897435897434, max: 126)
#
# Run: 79, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 32.78481012658228, max: 177)
#
# Run: 80, exploration: 0.01, score: 130
# Scores: (min: 8, avg: 34, max: 177)
#
# Run: 81, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 35.74074074074074, max: 177)
#
# Run: 82, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 37.707317073170735, max: 197)
#
# Run: 83, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 39.36144578313253, max: 197)
#
# Run: 84, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 41.38095238095238, max: 209)
#
# Run: 85, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 42.976470588235294, max: 209)
#
# Run: 86, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 44.651162790697676, max: 209)
#
# Run: 87, exploration: 0.01, score: 281
# Scores: (min: 8, avg: 47.367816091954026, max: 281)
#
# Run: 88, exploration: 0.01, score: 246
# Scores: (min: 8, avg: 49.625, max: 281)
#
# Run: 89, exploration: 0.01, score: 250
# Scores: (min: 8, avg: 51.87640449438202, max: 281)
#
# Run: 90, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 53.72222222222222, max: 281)
#
# Run: 91, exploration: 0.01, score: 236
# Scores: (min: 8, avg: 55.72527472527472, max: 281)
#
# Run: 92, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 57.26086956521739, max: 281)
#
# Run: 93, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 58.73118279569893, max: 281)
#
# Run: 94, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 59.819148936170215, max: 281)
#
# Run: 95, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 60.85263157894737, max: 281)
#
# Run: 96, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 61.864583333333336, max: 281)
#
# Run: 97, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 63.48453608247423, max: 281)
#
# Run: 98, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 64.5204081632653, max: 281)
#
# Run: 99, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 66.20202020202021, max: 281)
#
# Run: 100, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 67.32, max: 281)
#
# Run: 101, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 68.88, max: 281)
#
# Run: 102, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 70.61, max: 281)
#
# Run: 103, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 71.98, max: 281)
#
# Run: 104, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 73.77, max: 281)
#
# Run: 105, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 75.18, max: 281)
#
# Run: 106, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 76.75, max: 281)
#
# Run: 107, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 78.05, max: 281)
#
# Run: 108, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 79.46, max: 281)
#
# Run: 109, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 80.94, max: 281)
#
# Run: 110, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 82.72, max: 281)
#
# Run: 111, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 84.02, max: 281)
#
# Run: 112, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 86.16, max: 281)
#
# Run: 113, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 87.81, max: 281)
#
# Run: 114, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 89.39, max: 281)
#
# Run: 115, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 91.11, max: 281)
#
# Run: 116, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 92.82, max: 281)
#
# Run: 117, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 94.47, max: 281)
#
# Run: 118, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 96.03, max: 281)
#
# Run: 119, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 97.8, max: 281)
#
# Run: 120, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 99.34, max: 281)
#
# Run: 121, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 100.98, max: 281)
#
# Run: 122, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 102.36, max: 281)
#
# Run: 123, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 104.31, max: 281)
#
# Run: 124, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 106.08, max: 281)
#
# Run: 125, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 108.01, max: 281)
#
# Run: 126, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 109.49, max: 281)
#
# Run: 127, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 111.12, max: 281)
#
# Run: 128, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 112.88, max: 281)
#
# Run: 129, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 114.52, max: 281)
#
# Run: 130, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 116.52, max: 281)
#
# Run: 131, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 118.27, max: 281)
#
# Run: 132, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 119.94, max: 281)
#
# Run: 133, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 121.51, max: 281)
#
# Run: 134, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 123.07, max: 281)
#
# Run: 135, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 124.61, max: 281)
#
# Run: 136, exploration: 0.01, score: 182
# Scores: (min: 13, avg: 126.35, max: 281)
#
# Run: 137, exploration: 0.01, score: 244
# Scores: (min: 13, avg: 128.66, max: 281)
#
# Run: 138, exploration: 0.01, score: 184
# Scores: (min: 13, avg: 130.19, max: 281)
#
# Run: 139, exploration: 0.01, score: 177
# Scores: (min: 13, avg: 131.76, max: 281)
#
# Run: 140, exploration: 0.01, score: 177
# Scores: (min: 17, avg: 133.4, max: 281)
#
# Run: 141, exploration: 0.01, score: 92
# Scores: (min: 17, avg: 134.14, max: 281)
#
# Run: 142, exploration: 0.01, score: 169
# Scores: (min: 17, avg: 135.57, max: 281)
#
# Run: 143, exploration: 0.01, score: 238
# Scores: (min: 17, avg: 137.69, max: 281)
#
# Run: 144, exploration: 0.01, score: 199
# Scores: (min: 18, avg: 139.51, max: 281)
#
# Run: 145, exploration: 0.01, score: 171
# Scores: (min: 18, avg: 141.04, max: 281)
#
# Run: 146, exploration: 0.01, score: 166
# Scores: (min: 18, avg: 142.18, max: 281)
#
# Run: 147, exploration: 0.01, score: 202
# Scores: (min: 18, avg: 143.9, max: 281)
#
# Run: 148, exploration: 0.01, score: 161
# Scores: (min: 18, avg: 145.33, max: 281)
#
# Run: 149, exploration: 0.01, score: 214
# Scores: (min: 18, avg: 147.04, max: 281)
#
# Run: 150, exploration: 0.01, score: 273
# Scores: (min: 18, avg: 149.33, max: 281)
#
# Run: 151, exploration: 0.01, score: 426
# Scores: (min: 18, avg: 153.3, max: 426)
#
# Run: 152, exploration: 0.01, score: 185
# Scores: (min: 18, avg: 154.65, max: 426)
#
# Run: 153, exploration: 0.01, score: 500
# Scores: (min: 18, avg: 159.28, max: 500)
#
# Run: 154, exploration: 0.01, score: 500
# Scores: (min: 18, avg: 163.75, max: 500)
#
# Run: 155, exploration: 0.01, score: 472
# Scores: (min: 18, avg: 168.23, max: 500)
#
# Run: 156, exploration: 0.01, score: 178
# Scores: (min: 18, avg: 169.68, max: 500)
#
# Run: 157, exploration: 0.01, score: 500
# Scores: (min: 18, avg: 174.25, max: 500)
#
# Run: 158, exploration: 0.01, score: 291
# Scores: (min: 18, avg: 176.88, max: 500)
#
# Run: 159, exploration: 0.01, score: 182
# Scores: (min: 18, avg: 178.13, max: 500)
#
# Run: 160, exploration: 0.01, score: 158
# Scores: (min: 18, avg: 179.49, max: 500)
#
# Run: 161, exploration: 0.01, score: 118
# Scores: (min: 18, avg: 179.41, max: 500)
#
# Run: 162, exploration: 0.01, score: 163
# Scores: (min: 32, avg: 180.86, max: 500)
#
# Run: 163, exploration: 0.01, score: 126
# Scores: (min: 32, avg: 181.53, max: 500)
#
# Run: 164, exploration: 0.01, score: 166
# Scores: (min: 33, avg: 182.87, max: 500)
#
# Run: 165, exploration: 0.01, score: 234
# Scores: (min: 33, avg: 184.59, max: 500)
#
# Run: 166, exploration: 0.01, score: 87
# Scores: (min: 33, avg: 185.03, max: 500)
#
# Run: 167, exploration: 0.01, score: 159
# Scores: (min: 33, avg: 186.03, max: 500)
#
# Run: 168, exploration: 0.01, score: 162
# Scores: (min: 33, avg: 187.2, max: 500)
#
# Run: 169, exploration: 0.01, score: 173
# Scores: (min: 33, avg: 188.6, max: 500)
#
# Run: 170, exploration: 0.01, score: 134
# Scores: (min: 36, avg: 189.61, max: 500)
#
# Run: 171, exploration: 0.01, score: 64
# Scores: (min: 36, avg: 189.2, max: 500)
#
# Run: 172, exploration: 0.01, score: 184
# Scores: (min: 64, avg: 190.68, max: 500)
#
# Run: 173, exploration: 0.01, score: 327
# Scores: (min: 64, avg: 193.18, max: 500)
#
# Run: 174, exploration: 0.01, score: 204
# Scores: (min: 64, avg: 194.22, max: 500)
#
# Run: 175, exploration: 0.01, score: 333
# Scores: (min: 64, avg: 196.39, max: 500)
#
# Solved in 75 runs, 175 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.90  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.995, score: 21
# Scores: (min: 21, avg: 21, max: 21)
#
# Run: 2, exploration: 0.9416228069143757, score: 12
# Scores: (min: 12, avg: 16.5, max: 21)
#
# Run: 3, exploration: 0.8307187014821328, score: 26
# Scores: (min: 12, avg: 19.666666666666668, max: 26)
#
# Run: 4, exploration: 0.7861544476842928, score: 12
# Scores: (min: 12, avg: 17.75, max: 26)
#
# Run: 5, exploration: 0.6935613678313175, score: 26
# Scores: (min: 12, avg: 19.4, max: 26)
#
# Run: 6, exploration: 0.6180388156137953, score: 24
# Scores: (min: 12, avg: 20.166666666666668, max: 26)
#
# Run: 7, exploration: 0.5790496471185967, score: 14
# Scores: (min: 12, avg: 19.285714285714285, max: 26)
#
# Run: 8, exploration: 0.547986285490042, score: 12
# Scores: (min: 12, avg: 18.375, max: 26)
#
# Run: 9, exploration: 0.5238143793828016, score: 10
# Scores: (min: 10, avg: 17.444444444444443, max: 26)
#
# Run: 10, exploration: 0.500708706245853, score: 10
# Scores: (min: 10, avg: 16.7, max: 26)
#
# Run: 11, exploration: 0.47147873742168567, score: 13
# Scores: (min: 10, avg: 16.363636363636363, max: 26)
#
# Run: 12, exploration: 0.4484282034609769, score: 11
# Scores: (min: 10, avg: 15.916666666666666, max: 26)
#
# Run: 13, exploration: 0.4286478463299511, score: 10
# Scores: (min: 10, avg: 15.461538461538462, max: 26)
#
# Run: 14, exploration: 0.40769130904675194, score: 11
# Scores: (min: 10, avg: 15.142857142857142, max: 26)
#
# Run: 15, exploration: 0.3897078735047413, score: 10
# Scores: (min: 10, avg: 14.8, max: 26)
#
# Run: 16, exploration: 0.36880183088056995, score: 12
# Scores: (min: 10, avg: 14.625, max: 26)
#
# Run: 17, exploration: 0.3455358541129786, score: 14
# Scores: (min: 10, avg: 14.588235294117647, max: 26)
#
# Run: 18, exploration: 0.32864265128599696, score: 11
# Scores: (min: 10, avg: 14.38888888888889, max: 26)
#
# Run: 19, exploration: 0.3125753549412418, score: 11
# Scores: (min: 10, avg: 14.210526315789474, max: 26)
#
# Run: 20, exploration: 0.2987875242397482, score: 10
# Scores: (min: 10, avg: 14, max: 26)
#
# Run: 21, exploration: 0.27714603575484437, score: 16
# Scores: (min: 10, avg: 14.095238095238095, max: 26)
#
# Run: 22, exploration: 0.26227842021373715, score: 12
# Scores: (min: 10, avg: 14, max: 26)
#
# Run: 23, exploration: 0.2494556624678441, score: 11
# Scores: (min: 10, avg: 13.869565217391305, max: 26)
#
# Run: 24, exploration: 0.23607350863684065, score: 12
# Scores: (min: 10, avg: 13.791666666666666, max: 26)
#
# Run: 25, exploration: 0.22340924607110255, score: 12
# Scores: (min: 10, avg: 13.72, max: 26)
#
# Run: 26, exploration: 0.21142436319205632, score: 12
# Scores: (min: 10, avg: 13.653846153846153, max: 26)
#
# Run: 27, exploration: 0.20209834538617025, score: 10
# Scores: (min: 10, avg: 13.518518518518519, max: 26)
#
# Run: 28, exploration: 0.19415447453059972, score: 9
# Scores: (min: 9, avg: 13.357142857142858, max: 26)
#
# Run: 29, exploration: 0.18559023879528855, score: 10
# Scores: (min: 9, avg: 13.241379310344827, max: 26)
#
# Run: 30, exploration: 0.17740377510930716, score: 10
# Scores: (min: 9, avg: 13.133333333333333, max: 26)
#
# Run: 31, exploration: 0.16957841978827493, score: 10
# Scores: (min: 9, avg: 13.03225806451613, max: 26)
#
# Run: 32, exploration: 0.15967890763313974, score: 13
# Scores: (min: 9, avg: 13.03125, max: 26)
#
# Run: 33, exploration: 0.1526354036900377, score: 10
# Scores: (min: 9, avg: 12.93939393939394, max: 26)
#
# Run: 34, exploration: 0.14444721332374086, score: 12
# Scores: (min: 9, avg: 12.911764705882353, max: 26)
#
# Run: 35, exploration: 0.13807558583895513, score: 10
# Scores: (min: 9, avg: 12.82857142857143, max: 26)
#
# Run: 36, exploration: 0.13198501352907185, score: 10
# Scores: (min: 9, avg: 12.75, max: 26)
#
# Run: 37, exploration: 0.1261630989318213, score: 10
# Scores: (min: 9, avg: 12.675675675675675, max: 26)
#
# Run: 38, exploration: 0.11999500148501063, score: 11
# Scores: (min: 9, avg: 12.631578947368421, max: 26)
#
# Run: 39, exploration: 0.11470197137452155, score: 10
# Scores: (min: 9, avg: 12.564102564102564, max: 26)
#
# Run: 40, exploration: 0.10909420695870241, score: 11
# Scores: (min: 9, avg: 12.525, max: 26)
#
# Run: 41, exploration: 0.1042820154910064, score: 10
# Scores: (min: 9, avg: 12.463414634146341, max: 26)
#
# Run: 42, exploration: 0.09918368135888474, score: 11
# Scores: (min: 9, avg: 12.428571428571429, max: 26)
#
# Run: 43, exploration: 0.09386293109673778, score: 12
# Scores: (min: 9, avg: 12.418604651162791, max: 26)
#
# Run: 44, exploration: 0.08838347664452084, score: 13
# Scores: (min: 9, avg: 12.431818181818182, max: 26)
#
# Run: 45, exploration: 0.08406242000238873, score: 11
# Scores: (min: 9, avg: 12.4, max: 26)
#
# Run: 46, exploration: 0.08035439121179945, score: 10
# Scores: (min: 9, avg: 12.347826086956522, max: 26)
#
# Run: 47, exploration: 0.07566352740075044, score: 13
# Scores: (min: 9, avg: 12.361702127659575, max: 26)
#
# Run: 48, exploration: 0.07268942442628039, score: 9
# Scores: (min: 9, avg: 12.291666666666666, max: 26)
#
# Run: 49, exploration: 0.06983222438783, score: 9
# Scores: (min: 9, avg: 12.224489795918368, max: 26)
#
# Run: 50, exploration: 0.06641813604822402, score: 11
# Scores: (min: 9, avg: 12.2, max: 26)
#
# Run: 51, exploration: 0.06380744126877576, score: 9
# Scores: (min: 9, avg: 12.137254901960784, max: 26)
#
# Run: 52, exploration: 0.06129936495526111, score: 9
# Scores: (min: 9, avg: 12.076923076923077, max: 26)
#
# Run: 53, exploration: 0.05918580250061433, score: 8
# Scores: (min: 8, avg: 12, max: 26)
#
# Run: 54, exploration: 0.056575091797066025, score: 10
# Scores: (min: 8, avg: 11.962962962962964, max: 26)
#
# Run: 55, exploration: 0.0543512971290831, score: 9
# Scores: (min: 8, avg: 11.909090909090908, max: 26)
#
# Run: 56, exploration: 0.052477299559006776, score: 8
# Scores: (min: 8, avg: 11.839285714285714, max: 26)
#
# Run: 57, exploration: 0.050162503748802344, score: 10
# Scores: (min: 8, avg: 11.807017543859649, max: 26)
#
# Run: 58, exploration: 0.048432933065126825, score: 8
# Scores: (min: 8, avg: 11.741379310344827, max: 26)
#
# Run: 59, exploration: 0.04652918187562211, score: 9
# Scores: (min: 8, avg: 11.694915254237289, max: 26)
#
# Run: 60, exploration: 0.04447676004441063, score: 10
# Scores: (min: 8, avg: 11.666666666666666, max: 26)
#
# Run: 61, exploration: 0.04294323012606958, score: 8
# Scores: (min: 8, avg: 11.60655737704918, max: 26)
#
# Run: 62, exploration: 0.04104898613852031, score: 10
# Scores: (min: 8, avg: 11.580645161290322, max: 26)
#
# Run: 63, exploration: 0.03923829805195549, score: 10
# Scores: (min: 8, avg: 11.555555555555555, max: 26)
#
# Run: 64, exploration: 0.03769595998025326, score: 9
# Scores: (min: 8, avg: 11.515625, max: 26)
#
# Run: 65, exploration: 0.036396227662238566, score: 8
# Scores: (min: 8, avg: 11.461538461538462, max: 26)
#
# Run: 66, exploration: 0.03496560272750046, score: 9
# Scores: (min: 8, avg: 11.424242424242424, max: 26)
#
# Run: 67, exploration: 0.03359121130473201, score: 9
# Scores: (min: 8, avg: 11.388059701492537, max: 26)
#
# Run: 68, exploration: 0.032109488810599975, score: 10
# Scores: (min: 8, avg: 11.367647058823529, max: 26)
#
# Run: 69, exploration: 0.030693125720441184, score: 10
# Scores: (min: 8, avg: 11.347826086956522, max: 26)
#
# Run: 70, exploration: 0.02948667236521416, score: 9
# Scores: (min: 8, avg: 11.314285714285715, max: 26)
#
# Run: 71, exploration: 0.028186002814352063, score: 10
# Scores: (min: 8, avg: 11.295774647887324, max: 26)
#
# Run: 72, exploration: 0.02654058308574668, score: 13
# Scores: (min: 8, avg: 11.319444444444445, max: 26)
#
# Run: 73, exploration: 0.02536986677519817, score: 10
# Scores: (min: 8, avg: 11.301369863013699, max: 26)
#
# Run: 74, exploration: 0.024250791254731636, score: 10
# Scores: (min: 8, avg: 11.283783783783784, max: 26)
#
# Run: 75, exploration: 0.022835098131175, score: 13
# Scores: (min: 8, avg: 11.306666666666667, max: 26)
#
# Run: 76, exploration: 0.020246819920648168, score: 25
# Scores: (min: 8, avg: 11.486842105263158, max: 26)
#
# Run: 77, exploration: 0.017683979399301233, score: 28
# Scores: (min: 8, avg: 11.7012987012987, max: 28)
#
# Run: 78, exploration: 0.015601164601953134, score: 26
# Scores: (min: 8, avg: 11.884615384615385, max: 28)
#
# Run: 79, exploration: 0.01184203826198843, score: 56
# Scores: (min: 8, avg: 12.443037974683545, max: 56)
#
# Run: 80, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 13.2, max: 73)
#
# Run: 81, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 13.679012345679013, max: 73)
#
# Run: 82, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 14.548780487804878, max: 85)
#
# Run: 83, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 14.855421686746988, max: 85)
#
# Run: 84, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 15.107142857142858, max: 85)
#
# Run: 85, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 15.270588235294118, max: 85)
#
# Run: 86, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 15.569767441860465, max: 85)
#
# Run: 87, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 15.655172413793103, max: 85)
#
# Run: 88, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 15.818181818181818, max: 85)
#
# Run: 89, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 16.06741573033708, max: 85)
#
# Run: 90, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 16.333333333333332, max: 85)
#
# Run: 91, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 16.505494505494507, max: 85)
#
# Run: 92, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 16.891304347826086, max: 85)
#
# Run: 93, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 16.967741935483872, max: 85)
#
# Run: 94, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 17.148936170212767, max: 85)
#
# Run: 95, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 17.28421052631579, max: 85)
#
# Run: 96, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 17.40625, max: 85)
#
# Run: 97, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.391752577319586, max: 85)
#
# Run: 98, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 17.591836734693878, max: 85)
#
# Run: 99, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 17.656565656565657, max: 85)
#
# Run: 100, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 17.86, max: 85)
#
# Run: 101, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 18.15, max: 85)
#
# Run: 102, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 18.41, max: 85)
#
# Run: 103, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 18.45, max: 85)
#
# Run: 104, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 18.67, max: 85)
#
# Run: 105, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 19, max: 85)
#
# Run: 106, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 19.36, max: 85)
#
# Run: 107, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 19.82, max: 85)
#
# Run: 108, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 20.14, max: 85)
#
# Run: 109, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 20.36, max: 85)
#
# Run: 110, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 20.66, max: 85)
#
# Run: 111, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 20.89, max: 85)
#
# Run: 112, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 21.19, max: 85)
#
# Run: 113, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 21.41, max: 85)
#
# Run: 114, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 21.82, max: 85)
#
# Run: 115, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 22.86, max: 114)
#
# Run: 116, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 23.84, max: 114)
#
# Run: 117, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 24.29, max: 114)
#
# Run: 118, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 24.87, max: 114)
#
# Run: 119, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 25.59, max: 114)
#
# Run: 120, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 26.85, max: 136)
#
# Run: 121, exploration: 0.01, score: 103
# Scores: (min: 8, avg: 27.72, max: 136)
#
# Run: 122, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 29.16, max: 156)
#
# Run: 123, exploration: 0.01, score: 118
# Scores: (min: 8, avg: 30.23, max: 156)
#
# Run: 124, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 31.51, max: 156)
#
# Run: 125, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 32.63, max: 156)
#
# Run: 126, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 34.96, max: 245)
#
# Run: 127, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 36.4, max: 245)
#
# Run: 128, exploration: 0.01, score: 228
# Scores: (min: 8, avg: 38.59, max: 245)
#
# Run: 129, exploration: 0.01, score: 397
# Scores: (min: 8, avg: 42.46, max: 397)
#
# Run: 130, exploration: 0.01, score: 332
# Scores: (min: 8, avg: 45.68, max: 397)
#
# Run: 131, exploration: 0.01, score: 304
# Scores: (min: 8, avg: 48.62, max: 397)
#
# Run: 132, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 50.2, max: 397)
#
# Run: 133, exploration: 0.01, score: 381
# Scores: (min: 8, avg: 53.91, max: 397)
#
# Run: 134, exploration: 0.01, score: 203
# Scores: (min: 8, avg: 55.82, max: 397)
#
# Run: 135, exploration: 0.01, score: 304
# Scores: (min: 8, avg: 58.76, max: 397)
#
# Run: 136, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 61.2, max: 397)
#
# Run: 137, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 63.4, max: 397)
#
# Run: 138, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 65.22, max: 397)
#
# Run: 139, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 67.31, max: 397)
#
# Run: 140, exploration: 0.01, score: 227
# Scores: (min: 8, avg: 69.47, max: 397)
#
# Run: 141, exploration: 0.01, score: 232
# Scores: (min: 8, avg: 71.69, max: 397)
#
# Run: 142, exploration: 0.01, score: 253
# Scores: (min: 8, avg: 74.11, max: 397)
#
# Run: 143, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 75.94, max: 397)
#
# Run: 144, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 77.58, max: 397)
#
# Run: 145, exploration: 0.01, score: 257
# Scores: (min: 8, avg: 80.04, max: 397)
#
# Run: 146, exploration: 0.01, score: 293
# Scores: (min: 8, avg: 82.87, max: 397)
#
# Run: 147, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 85.11, max: 397)
#
# Run: 148, exploration: 0.01, score: 286
# Scores: (min: 8, avg: 87.88, max: 397)
#
# Run: 149, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 89.02, max: 397)
#
# Run: 150, exploration: 0.01, score: 280
# Scores: (min: 8, avg: 91.71, max: 397)
#
# Run: 151, exploration: 0.01, score: 402
# Scores: (min: 8, avg: 95.64, max: 402)
#
# Run: 152, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 100.55, max: 500)
#
# Run: 153, exploration: 0.01, score: 161
# Scores: (min: 8, avg: 102.08, max: 500)
#
# Run: 154, exploration: 0.01, score: 163
# Scores: (min: 8, avg: 103.61, max: 500)
#
# Run: 155, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 104.01, max: 500)
#
# Run: 156, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 104.57, max: 500)
#
# Run: 157, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 105.57, max: 500)
#
# Run: 158, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 105.58, max: 500)
#
# Run: 159, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 107.5, max: 500)
#
# Run: 160, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 108.96, max: 500)
#
# Run: 161, exploration: 0.01, score: 249
# Scores: (min: 8, avg: 111.37, max: 500)
#
# Run: 162, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 113.29, max: 500)
#
# Run: 163, exploration: 0.01, score: 347
# Scores: (min: 8, avg: 116.66, max: 500)
#
# Run: 164, exploration: 0.01, score: 93
# Scores: (min: 8, avg: 117.5, max: 500)
#
# Run: 165, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 117.56, max: 500)
#
# Run: 166, exploration: 0.01, score: 339
# Scores: (min: 9, avg: 120.86, max: 500)
#
# Run: 167, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 122.2, max: 500)
#
# Run: 168, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 123.66, max: 500)
#
# Run: 169, exploration: 0.01, score: 223
# Scores: (min: 9, avg: 125.79, max: 500)
#
# Run: 170, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 127, max: 500)
#
# Run: 171, exploration: 0.01, score: 359
# Scores: (min: 9, avg: 130.49, max: 500)
#
# Run: 172, exploration: 0.01, score: 315
# Scores: (min: 9, avg: 133.51, max: 500)
#
# Run: 173, exploration: 0.01, score: 277
# Scores: (min: 9, avg: 136.18, max: 500)
#
# Run: 174, exploration: 0.01, score: 219
# Scores: (min: 9, avg: 138.27, max: 500)
#
# Run: 175, exploration: 0.01, score: 265
# Scores: (min: 9, avg: 140.79, max: 500)
#
# Run: 176, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 142.6, max: 500)
#
# Run: 177, exploration: 0.01, score: 355
# Scores: (min: 9, avg: 145.87, max: 500)
#
# Run: 178, exploration: 0.01, score: 216
# Scores: (min: 9, avg: 147.77, max: 500)
#
# Run: 179, exploration: 0.01, score: 371
# Scores: (min: 9, avg: 150.92, max: 500)
#
# Run: 180, exploration: 0.01, score: 292
# Scores: (min: 9, avg: 153.11, max: 500)
#
# Run: 181, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 154.52, max: 500)
#
# Run: 182, exploration: 0.01, score: 282
# Scores: (min: 9, avg: 156.49, max: 500)
#
# Run: 183, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 161.09, max: 500)
#
# Run: 184, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 162.81, max: 500)
#
# Run: 185, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 164.27, max: 500)
#
# Run: 186, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 165.2, max: 500)
#
# Run: 187, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 166.41, max: 500)
#
# Run: 188, exploration: 0.01, score: 256
# Scores: (min: 9, avg: 168.67, max: 500)
#
# Run: 189, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 170.27, max: 500)
#
# Run: 190, exploration: 0.01, score: 271
# Scores: (min: 9, avg: 172.58, max: 500)
#
# Run: 191, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 173.32, max: 500)
#
# Run: 192, exploration: 0.01, score: 320
# Scores: (min: 9, avg: 176, max: 500)
#
# Run: 193, exploration: 0.01, score: 264
# Scores: (min: 9, avg: 178.4, max: 500)
#
# Run: 194, exploration: 0.01, score: 196
# Scores: (min: 9, avg: 180.02, max: 500)
#
# Run: 195, exploration: 0.01, score: 447
# Scores: (min: 9, avg: 184.19, max: 500)
#
# Run: 196, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 185.67, max: 500)
#
# Run: 197, exploration: 0.01, score: 239
# Scores: (min: 9, avg: 187.9, max: 500)
#
# Run: 198, exploration: 0.01, score: 196
# Scores: (min: 9, avg: 189.49, max: 500)
#
# Run: 199, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 190.63, max: 500)
#
# Run: 200, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 190.43, max: 500)
#
# Run: 201, exploration: 0.01, score: 116
# Scores: (min: 9, avg: 191.09, max: 500)
#
# Run: 202, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 191.81, max: 500)
#
# Run: 203, exploration: 0.01, score: 81
# Scores: (min: 9, avg: 192.32, max: 500)
#
# Run: 204, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 193.03, max: 500)
#
# Run: 205, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 192.87, max: 500)
#
# Run: 206, exploration: 0.01, score: 64
# Scores: (min: 9, avg: 192.91, max: 500)
#
# Run: 207, exploration: 0.01, score: 87
# Scores: (min: 9, avg: 193.18, max: 500)
#
# Run: 208, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 193.08, max: 500)
#
# Run: 209, exploration: 0.01, score: 91
# Scores: (min: 9, avg: 193.67, max: 500)
#
# Run: 210, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 195.03, max: 500)
#
# Solved in 110 runs, 210 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-6-5d00f563e48c> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.005  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9369146928798039, score: 33
# Scores: (min: 33, avg: 33, max: 33)
#
# Run: 2, exploration: 0.778312557068642, score: 38
# Scores: (min: 33, avg: 35.5, max: 38)
#
# Run: 3, exploration: 0.7219385759785162, score: 16
# Scores: (min: 16, avg: 29, max: 38)
#
# Run: 4, exploration: 0.653073201944699, score: 21
# Scores: (min: 16, avg: 27, max: 38)
#
# Run: 5, exploration: 0.5937455908197752, score: 20
# Scores: (min: 16, avg: 25.6, max: 38)
#
# Run: 6, exploration: 0.5344229416520513, score: 22
# Scores: (min: 16, avg: 25, max: 38)
#
# Run: 7, exploration: 0.4982051627146237, score: 15
# Scores: (min: 15, avg: 23.571428571428573, max: 38)
#
# Run: 8, exploration: 0.47622912292284103, score: 10
# Scores: (min: 10, avg: 21.875, max: 38)
#
# Run: 9, exploration: 0.4417353564707963, score: 16
# Scores: (min: 10, avg: 21.22222222222222, max: 38)
#
# Run: 10, exploration: 0.41386834584198684, score: 14
# Scores: (min: 10, avg: 20.5, max: 38)
#
# Run: 11, exploration: 0.3976004408064698, score: 9
# Scores: (min: 9, avg: 19.454545454545453, max: 38)
#
# Run: 12, exploration: 0.3800621177172763, score: 10
# Scores: (min: 9, avg: 18.666666666666668, max: 38)
#
# Run: 13, exploration: 0.3632974174544486, score: 10
# Scores: (min: 9, avg: 18, max: 38)
#
# Run: 14, exploration: 0.3472722151889232, score: 10
# Scores: (min: 9, avg: 17.428571428571427, max: 38)
#
# Run: 15, exploration: 0.3173112652388396, score: 19
# Scores: (min: 9, avg: 17.533333333333335, max: 38)
#
# Run: 16, exploration: 0.3017979588795719, score: 11
# Scores: (min: 9, avg: 17.125, max: 38)
#
# Run: 17, exploration: 0.28704309604425327, score: 11
# Scores: (min: 9, avg: 16.764705882352942, max: 38)
#
# Run: 18, exploration: 0.2743815040481898, score: 10
# Scores: (min: 9, avg: 16.38888888888889, max: 38)
#
# Run: 19, exploration: 0.2583638820072446, score: 13
# Scores: (min: 9, avg: 16.210526315789473, max: 38)
#
# Run: 20, exploration: 0.24696734223472733, score: 10
# Scores: (min: 9, avg: 15.9, max: 38)
#
# Run: 21, exploration: 0.23607350863684065, score: 10
# Scores: (min: 9, avg: 15.619047619047619, max: 38)
#
# Run: 22, exploration: 0.22566020663225933, score: 10
# Scores: (min: 9, avg: 15.363636363636363, max: 38)
#
# Run: 23, exploration: 0.1678868750508869, score: 60
# Scores: (min: 9, avg: 17.304347826086957, max: 60)
#
# Run: 24, exploration: 0.12743425563174798, score: 56
# Scores: (min: 9, avg: 18.916666666666668, max: 60)
#
# Run: 25, exploration: 0.09770335251664321, score: 54
# Scores: (min: 9, avg: 20.32, max: 60)
#
# Run: 26, exploration: 0.07379076075438468, score: 57
# Scores: (min: 9, avg: 21.73076923076923, max: 60)
#
# Run: 27, exploration: 0.0378853869148274, score: 134
# Scores: (min: 9, avg: 25.88888888888889, max: 134)
#
# Run: 28, exploration: 0.02524301744132218, score: 82
# Scores: (min: 9, avg: 27.892857142857142, max: 134)
#
# Run: 29, exploration: 0.01166529436067347, score: 155
# Scores: (min: 9, avg: 32.275862068965516, max: 155)
#
# Run: 30, exploration: 0.01, score: 208
# Scores: (min: 9, avg: 38.13333333333333, max: 208)
#
# Run: 31, exploration: 0.01, score: 182
# Scores: (min: 9, avg: 42.774193548387096, max: 208)
#
# Run: 32, exploration: 0.01, score: 222
# Scores: (min: 9, avg: 48.375, max: 222)
#
# Run: 33, exploration: 0.01, score: 224
# Scores: (min: 9, avg: 53.696969696969695, max: 224)
#
# Run: 34, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 58.35294117647059, max: 224)
#
# Run: 35, exploration: 0.01, score: 210
# Scores: (min: 9, avg: 62.68571428571428, max: 224)
#
# Run: 36, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 66.66666666666667, max: 224)
#
# Run: 37, exploration: 0.01, score: 251
# Scores: (min: 9, avg: 71.64864864864865, max: 251)
#
# Run: 38, exploration: 0.01, score: 280
# Scores: (min: 9, avg: 77.13157894736842, max: 280)
#
# Run: 39, exploration: 0.01, score: 207
# Scores: (min: 9, avg: 80.46153846153847, max: 280)
#
# Run: 40, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 82.675, max: 280)
#
# Run: 41, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 85.41463414634147, max: 280)
#
# Run: 42, exploration: 0.01, score: 223
# Scores: (min: 9, avg: 88.69047619047619, max: 280)
#
# Run: 43, exploration: 0.01, score: 202
# Scores: (min: 9, avg: 91.32558139534883, max: 280)
#
# Run: 44, exploration: 0.01, score: 243
# Scores: (min: 9, avg: 94.77272727272727, max: 280)
#
# Run: 45, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 96.5111111111111, max: 280)
#
# Run: 46, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 97.58695652173913, max: 280)
#
# Run: 47, exploration: 0.01, score: 194
# Scores: (min: 9, avg: 99.63829787234043, max: 280)
#
# Run: 48, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 101.22916666666667, max: 280)
#
# Run: 49, exploration: 0.01, score: 242
# Scores: (min: 9, avg: 104.10204081632654, max: 280)
#
# Run: 50, exploration: 0.01, score: 219
# Scores: (min: 9, avg: 106.4, max: 280)
#
# Run: 51, exploration: 0.01, score: 273
# Scores: (min: 9, avg: 109.66666666666667, max: 280)
#
# Run: 52, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 111.38461538461539, max: 280)
#
# Run: 53, exploration: 0.01, score: 185
# Scores: (min: 9, avg: 112.77358490566037, max: 280)
#
# Run: 54, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 114.29629629629629, max: 280)
#
# Run: 55, exploration: 0.01, score: 286
# Scores: (min: 9, avg: 117.41818181818182, max: 286)
#
# Run: 56, exploration: 0.01, score: 270
# Scores: (min: 9, avg: 120.14285714285714, max: 286)
#
# Run: 57, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 120.6140350877193, max: 286)
#
# Run: 58, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 121.60344827586206, max: 286)
#
# Run: 59, exploration: 0.01, score: 244
# Scores: (min: 9, avg: 123.67796610169492, max: 286)
#
# Run: 60, exploration: 0.01, score: 234
# Scores: (min: 9, avg: 125.51666666666667, max: 286)
#
# Run: 61, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 127.32786885245902, max: 286)
#
# Run: 62, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 128.0483870967742, max: 286)
#
# Run: 63, exploration: 0.01, score: 301
# Scores: (min: 9, avg: 130.79365079365078, max: 301)
#
# Run: 64, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 131.140625, max: 301)
#
# Run: 65, exploration: 0.01, score: 214
# Scores: (min: 9, avg: 132.41538461538462, max: 301)
#
# Run: 66, exploration: 0.01, score: 197
# Scores: (min: 9, avg: 133.3939393939394, max: 301)
#
# Run: 67, exploration: 0.01, score: 185
# Scores: (min: 9, avg: 134.16417910447763, max: 301)
#
# Run: 68, exploration: 0.01, score: 274
# Scores: (min: 9, avg: 136.22058823529412, max: 301)
#
# Run: 69, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 136.57971014492753, max: 301)
#
# Run: 70, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 136.57142857142858, max: 301)
#
# Run: 71, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 136.73239436619718, max: 301)
#
# Run: 72, exploration: 0.01, score: 240
# Scores: (min: 9, avg: 138.16666666666666, max: 301)
#
# Run: 73, exploration: 0.01, score: 203
# Scores: (min: 9, avg: 139.05479452054794, max: 301)
#
# Run: 74, exploration: 0.01, score: 300
# Scores: (min: 9, avg: 141.22972972972974, max: 301)
#
# Run: 75, exploration: 0.01, score: 229
# Scores: (min: 9, avg: 142.4, max: 301)
#
# Run: 76, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 142.81578947368422, max: 301)
#
# Run: 77, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 142.8181818181818, max: 301)
#
# Run: 78, exploration: 0.01, score: 243
# Scores: (min: 9, avg: 144.10256410256412, max: 301)
#
# Run: 79, exploration: 0.01, score: 316
# Scores: (min: 9, avg: 146.27848101265823, max: 316)
#
# Run: 80, exploration: 0.01, score: 352
# Scores: (min: 9, avg: 148.85, max: 352)
#
# Run: 81, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 149.09876543209876, max: 352)
#
# Run: 82, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 149.109756097561, max: 352)
#
# Run: 83, exploration: 0.01, score: 231
# Scores: (min: 9, avg: 150.09638554216866, max: 352)
#
# Run: 84, exploration: 0.01, score: 357
# Scores: (min: 9, avg: 152.5595238095238, max: 357)
#
# Run: 85, exploration: 0.01, score: 233
# Scores: (min: 9, avg: 153.50588235294117, max: 357)
#
# Run: 86, exploration: 0.01, score: 234
# Scores: (min: 9, avg: 154.4418604651163, max: 357)
#
# Run: 87, exploration: 0.01, score: 264
# Scores: (min: 9, avg: 155.70114942528735, max: 357)
#
# Run: 88, exploration: 0.01, score: 216
# Scores: (min: 9, avg: 156.38636363636363, max: 357)
#
# Run: 89, exploration: 0.01, score: 258
# Scores: (min: 9, avg: 157.52808988764045, max: 357)
#
# Run: 90, exploration: 0.01, score: 406
# Scores: (min: 9, avg: 160.2888888888889, max: 406)
#
# Run: 91, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 160.42857142857142, max: 406)
#
# Run: 92, exploration: 0.01, score: 186
# Scores: (min: 9, avg: 160.70652173913044, max: 406)
#
# Run: 93, exploration: 0.01, score: 235
# Scores: (min: 9, avg: 161.50537634408602, max: 406)
#
# Run: 94, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 162.2340425531915, max: 406)
#
# Run: 95, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 162.81052631578947, max: 406)
#
# Run: 96, exploration: 0.01, score: 226
# Scores: (min: 9, avg: 163.46875, max: 406)
#
# Run: 97, exploration: 0.01, score: 186
# Scores: (min: 9, avg: 163.70103092783506, max: 406)
#
# Run: 98, exploration: 0.01, score: 273
# Scores: (min: 9, avg: 164.81632653061226, max: 406)
#
# Run: 99, exploration: 0.01, score: 223
# Scores: (min: 9, avg: 165.40404040404042, max: 406)
#
# Run: 100, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 165.31, max: 406)
#
# Run: 101, exploration: 0.01, score: 250
# Scores: (min: 9, avg: 167.48, max: 406)
#
# Run: 102, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 168.43, max: 406)
#
# Run: 103, exploration: 0.01, score: 277
# Scores: (min: 9, avg: 171.04, max: 406)
#
# Run: 104, exploration: 0.01, score: 421
# Scores: (min: 9, avg: 175.04, max: 421)
#
# Run: 105, exploration: 0.01, score: 347
# Scores: (min: 9, avg: 178.31, max: 421)
#
# Run: 106, exploration: 0.01, score: 416
# Scores: (min: 9, avg: 182.25, max: 421)
#
# Run: 107, exploration: 0.01, score: 243
# Scores: (min: 9, avg: 184.53, max: 421)
#
# Run: 108, exploration: 0.01, score: 288
# Scores: (min: 9, avg: 187.31, max: 421)
#
# Run: 109, exploration: 0.01, score: 436
# Scores: (min: 9, avg: 191.51, max: 436)
#
# Run: 110, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 196.37, max: 500)
#
# Solved in 10 runs, 110 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-6-5d00f563e48c> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 0.9  
EXPLORATION_MIN = 0.02  
EXPLORATION_DECAY = 0.8  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.8390886103705794, score: 55
# Scores: (min: 55, avg: 55, max: 55)
#
# Run: 2, exploration: 0.7590483508202912, score: 21
# Scores: (min: 21, avg: 38, max: 55)
#
# Run: 3, exploration: 0.7292124703704616, score: 9
# Scores: (min: 9, avg: 28.333333333333332, max: 55)
#
# Run: 4, exploration: 0.6832098777212641, score: 14
# Scores: (min: 9, avg: 24.75, max: 55)
#
# Run: 5, exploration: 0.653073201944699, score: 10
# Scores: (min: 9, avg: 21.8, max: 55)
#
# Run: 6, exploration: 0.5937455908197752, score: 20
# Scores: (min: 9, avg: 21.5, max: 55)
#
# Run: 7, exploration: 0.5452463540625918, score: 18
# Scores: (min: 9, avg: 21, max: 55)
#
# Run: 8, exploration: 0.5211953074858876, score: 10
# Scores: (min: 9, avg: 19.625, max: 55)
#
# Run: 9, exploration: 0.4883155414435353, score: 14
# Scores: (min: 9, avg: 19, max: 55)
#
# Run: 10, exploration: 0.457510005540005, score: 14
# Scores: (min: 9, avg: 18.5, max: 55)
#
# Run: 11, exploration: 0.43732904629000013, score: 10
# Scores: (min: 9, avg: 17.727272727272727, max: 55)
#
# Run: 12, exploration: 0.4180382776616619, score: 10
# Scores: (min: 9, avg: 17.083333333333332, max: 55)
#
# Run: 13, exploration: 0.39166620452737816, score: 14
# Scores: (min: 9, avg: 16.846153846153847, max: 55)
#
# Run: 14, exploration: 0.3632974174544486, score: 16
# Scores: (min: 9, avg: 16.785714285714285, max: 55)
#
# Run: 15, exploration: 0.3472722151889232, score: 10
# Scores: (min: 9, avg: 16.333333333333332, max: 55)
#
# Run: 16, exploration: 0.33195389135223546, score: 10
# Scores: (min: 9, avg: 15.9375, max: 55)
#
# Run: 17, exploration: 0.31890579420988907, score: 9
# Scores: (min: 9, avg: 15.529411764705882, max: 55)
#
# Run: 18, exploration: 0.30483872516307353, score: 10
# Scores: (min: 9, avg: 15.222222222222221, max: 55)
#
# Run: 19, exploration: 0.2884855236625661, score: 12
# Scores: (min: 9, avg: 15.052631578947368, max: 55)
#
# Run: 20, exploration: 0.27714603575484437, score: 9
# Scores: (min: 9, avg: 14.75, max: 55)
#
# Run: 21, exploration: 0.2662522686041882, score: 9
# Scores: (min: 9, avg: 14.476190476190476, max: 55)
#
# Run: 22, exploration: 0.25450776877280124, score: 10
# Scores: (min: 9, avg: 14.272727272727273, max: 55)
#
# Run: 23, exploration: 0.23965031961336, score: 13
# Scores: (min: 9, avg: 14.217391304347826, max: 55)
#
# Run: 24, exploration: 0.22453190559909803, score: 14
# Scores: (min: 9, avg: 14.208333333333334, max: 55)
#
# Run: 25, exploration: 0.21570623976979014, score: 9
# Scores: (min: 9, avg: 14, max: 55)
#
# Run: 26, exploration: 0.19709615934585656, score: 19
# Scores: (min: 9, avg: 14.192307692307692, max: 55)
#
# Run: 27, exploration: 0.18840216465300522, score: 10
# Scores: (min: 9, avg: 14.037037037037036, max: 55)
#
# Run: 28, exploration: 0.1800916657318127, score: 10
# Scores: (min: 9, avg: 13.892857142857142, max: 55)
#
# Run: 29, exploration: 0.17043057265153258, score: 12
# Scores: (min: 9, avg: 13.827586206896552, max: 55)
#
# Run: 30, exploration: 0.16128775296900558, score: 12
# Scores: (min: 9, avg: 13.766666666666667, max: 55)
#
# Run: 31, exploration: 0.1534024157688821, score: 11
# Scores: (min: 9, avg: 13.67741935483871, max: 55)
#
# Run: 32, exploration: 0.1473726336968319, score: 9
# Scores: (min: 9, avg: 13.53125, max: 55)
#
# Run: 33, exploration: 0.14016760486247823, score: 11
# Scores: (min: 9, avg: 13.454545454545455, max: 55)
#
# Run: 34, exploration: 0.1346580429260134, score: 9
# Scores: (min: 9, avg: 13.323529411764707, max: 55)
#
# Run: 35, exploration: 0.12743425563174798, score: 12
# Scores: (min: 9, avg: 13.285714285714286, max: 55)
#
# Run: 36, exploration: 0.12120401149972035, score: 11
# Scores: (min: 9, avg: 13.222222222222221, max: 55)
#
# Run: 37, exploration: 0.11585765144771248, score: 10
# Scores: (min: 9, avg: 13.135135135135135, max: 55)
#
# Run: 38, exploration: 0.11186295456362313, score: 8
# Scores: (min: 8, avg: 13, max: 55)
#
# Run: 39, exploration: 0.10746596228306791, score: 9
# Scores: (min: 8, avg: 12.897435897435898, max: 55)
#
# Run: 40, exploration: 0.10376060541355137, score: 8
# Scores: (min: 8, avg: 12.775, max: 55)
#
# Run: 41, exploration: 0.09868776295209031, score: 11
# Scores: (min: 8, avg: 12.731707317073171, max: 55)
#
# Run: 42, exploration: 0.09528507271768329, score: 8
# Scores: (min: 8, avg: 12.619047619047619, max: 55)
#
# Run: 43, exploration: 0.0906265979439563, score: 11
# Scores: (min: 8, avg: 12.581395348837209, max: 55)
#
# Run: 44, exploration: 0.08406242000238873, score: 16
# Scores: (min: 8, avg: 12.659090909090908, max: 55)
#
# Run: 45, exploration: 0.07915509187866444, score: 13
# Scores: (min: 8, avg: 12.666666666666666, max: 55)
#
# Run: 46, exploration: 0.07528520976374668, score: 11
# Scores: (min: 8, avg: 12.630434782608695, max: 55)
#
# Run: 47, exploration: 0.07196434741762824, score: 10
# Scores: (min: 8, avg: 12.574468085106384, max: 55)
#
# Run: 48, exploration: 0.0691356479495614, score: 9
# Scores: (min: 8, avg: 12.5, max: 55)
#
# Run: 49, exploration: 0.06445033334388098, score: 15
# Scores: (min: 8, avg: 12.551020408163266, max: 55)
#
# Run: 50, exploration: 0.061607401965086545, score: 10
# Scores: (min: 8, avg: 12.5, max: 55)
#
# Run: 51, exploration: 0.058889873488111255, score: 10
# Scores: (min: 8, avg: 12.450980392156863, max: 55)
#
# Run: 52, exploration: 0.05601075525639029, score: 11
# Scores: (min: 8, avg: 12.423076923076923, max: 55)
#
# Run: 53, exploration: 0.052741004581916356, score: 13
# Scores: (min: 8, avg: 12.433962264150944, max: 55)
#
# Run: 54, exploration: 0.05092252885731386, score: 8
# Scores: (min: 8, avg: 12.351851851851851, max: 55)
#
# Run: 55, exploration: 0.04867631463831842, score: 10
# Scores: (min: 8, avg: 12.309090909090909, max: 55)
#
# Run: 56, exploration: 0.04652918187562211, score: 10
# Scores: (min: 8, avg: 12.267857142857142, max: 55)
#
# Run: 57, exploration: 0.04447676004441063, score: 10
# Scores: (min: 8, avg: 12.228070175438596, max: 55)
#
# Run: 58, exploration: 0.04294323012606958, score: 8
# Scores: (min: 8, avg: 12.155172413793103, max: 55)
#
# Run: 59, exploration: 0.04104898613852031, score: 10
# Scores: (min: 8, avg: 12.11864406779661, max: 55)
#
# Run: 60, exploration: 0.03904210656169572, score: 11
# Scores: (min: 8, avg: 12.1, max: 55)
#
# Run: 61, exploration: 0.03657912327863173, score: 14
# Scores: (min: 8, avg: 12.131147540983607, max: 55)
#
# Run: 62, exploration: 0.03461682084029365, score: 12
# Scores: (min: 8, avg: 12.129032258064516, max: 55)
#
# Run: 63, exploration: 0.03325613897196732, score: 9
# Scores: (min: 8, avg: 12.079365079365079, max: 55)
#
# Run: 64, exploration: 0.03100237440513238, score: 15
# Scores: (min: 8, avg: 12.125, max: 55)
#
# Run: 65, exploration: 0.029634846598205186, score: 10
# Scores: (min: 8, avg: 12.092307692307692, max: 55)
#
# Run: 66, exploration: 0.0280450728002803, score: 12
# Scores: (min: 8, avg: 12.090909090909092, max: 55)
#
# Run: 67, exploration: 0.024991218342344988, score: 24
# Scores: (min: 8, avg: 12.26865671641791, max: 55)
#
# Run: 68, exploration: 0.024008889611965685, score: 9
# Scores: (min: 8, avg: 12.220588235294118, max: 55)
#
# Run: 69, exploration: 0.022047758717570132, score: 18
# Scores: (min: 8, avg: 12.304347826086957, max: 55)
#
# Run: 70, exploration: 0.021075222784267326, score: 10
# Scores: (min: 8, avg: 12.271428571428572, max: 55)
#
# Run: 71, exploration: 0.019844910434467605, score: 13
# Scores: (min: 8, avg: 12.28169014084507, max: 55)
#
# Run: 72, exploration: 0.018500023224111744, score: 15
# Scores: (min: 8, avg: 12.319444444444445, max: 55)
#
# Run: 73, exploration: 0.017332943577287888, score: 14
# Scores: (min: 8, avg: 12.342465753424657, max: 55)
#
# Run: 74, exploration: 0.016651638319386028, score: 9
# Scores: (min: 8, avg: 12.297297297297296, max: 55)
#
# Run: 75, exploration: 0.015523158778943369, score: 15
# Scores: (min: 8, avg: 12.333333333333334, max: 55)
#
# Run: 76, exploration: 0.014838425699981627, score: 10
# Scores: (min: 8, avg: 12.302631578947368, max: 55)
#
# Run: 77, exploration: 0.014183896485845416, score: 10
# Scores: (min: 8, avg: 12.272727272727273, max: 55)
#
# Run: 78, exploration: 0.013558238831322046, score: 10
# Scores: (min: 8, avg: 12.243589743589743, max: 55)
#
# Run: 79, exploration: 0.011782828070678488, score: 29
# Scores: (min: 8, avg: 12.455696202531646, max: 55)
#
# Run: 80, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 12.975, max: 55)
#
# Run: 81, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 13.08641975308642, max: 55)
#
# Run: 82, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 13.158536585365853, max: 55)
#
# Run: 83, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 13.662650602409638, max: 55)
#
# Run: 84, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 14, max: 55)
#
# Run: 85, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.141176470588235, max: 55)
#
# Run: 86, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 14.36046511627907, max: 55)
#
# Run: 87, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 14.988505747126437, max: 69)
#
# Run: 88, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 15.545454545454545, max: 69)
#
# Run: 89, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 16.15730337078652, max: 70)
#
# Run: 90, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 17.344444444444445, max: 123)
#
# Run: 91, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 18.956043956043956, max: 164)
#
# Run: 92, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 19.92391304347826, max: 164)
#
# Run: 93, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 21.612903225806452, max: 177)
#
# Run: 94, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 22.925531914893618, max: 177)
#
# Run: 95, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 24.68421052631579, max: 190)
#
# Run: 96, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 26.447916666666668, max: 194)
#
# Run: 97, exploration: 0.01, score: 333
# Scores: (min: 8, avg: 29.608247422680414, max: 333)
#
# Run: 98, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 31.112244897959183, max: 333)
#
# Run: 99, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 32.494949494949495, max: 333)
#
# Run: 100, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 33.61, max: 333)
#
# Run: 101, exploration: 0.01, score: 157
# Scores: (min: 8, avg: 34.63, max: 333)
#
# Run: 102, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 36.11, max: 333)
#
# Run: 103, exploration: 0.01, score: 343
# Scores: (min: 8, avg: 39.45, max: 343)
#
# Run: 104, exploration: 0.01, score: 271
# Scores: (min: 8, avg: 42.02, max: 343)
#
# Run: 105, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 43.81, max: 343)
#
# Run: 106, exploration: 0.01, score: 227
# Scores: (min: 8, avg: 45.88, max: 343)
#
# Run: 107, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 47.95, max: 343)
#
# Run: 108, exploration: 0.01, score: 296
# Scores: (min: 8, avg: 50.81, max: 343)
#
# Run: 109, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 52.23, max: 343)
#
# Run: 110, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 53.86, max: 343)
#
# Run: 111, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 55.5, max: 343)
#
# Run: 112, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 57.12, max: 343)
#
# Run: 113, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 58.39, max: 343)
#
# Run: 114, exploration: 0.01, score: 266
# Scores: (min: 8, avg: 60.89, max: 343)
#
# Run: 115, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 62.64, max: 343)
#
# Run: 116, exploration: 0.01, score: 249
# Scores: (min: 8, avg: 65.03, max: 343)
#
# Run: 117, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 66.7, max: 343)
#
# Run: 118, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 68.59, max: 343)
#
# Run: 119, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 70.62, max: 343)
#
# Run: 120, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 72.26, max: 343)
#
# Run: 121, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 74.16, max: 343)
#
# Run: 122, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 75.87, max: 343)
#
# Run: 123, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 77.43, max: 343)
#
# Run: 124, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 79.15, max: 343)
#
# Run: 125, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 80.79, max: 343)
#
# Run: 126, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 82.78, max: 343)
#
# Run: 127, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 84.34, max: 343)
#
# Run: 128, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 87.34, max: 343)
#
# Run: 129, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 89.28, max: 343)
#
# Run: 130, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 91.4, max: 343)
#
# Run: 131, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 92.66, max: 343)
#
# Run: 132, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 94.4, max: 343)
#
# Run: 133, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 96.45, max: 343)
#
# Run: 134, exploration: 0.01, score: 309
# Scores: (min: 8, avg: 99.45, max: 343)
#
# Run: 135, exploration: 0.01, score: 283
# Scores: (min: 8, avg: 102.16, max: 343)
#
# Run: 136, exploration: 0.01, score: 269
# Scores: (min: 8, avg: 104.74, max: 343)
#
# Run: 137, exploration: 0.01, score: 203
# Scores: (min: 8, avg: 106.67, max: 343)
#
# Run: 138, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 108.27, max: 343)
#
# Run: 139, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 109.72, max: 343)
#
# Run: 140, exploration: 0.01, score: 277
# Scores: (min: 8, avg: 112.41, max: 343)
#
# Run: 141, exploration: 0.01, score: 222
# Scores: (min: 8, avg: 114.52, max: 343)
#
# Run: 142, exploration: 0.01, score: 317
# Scores: (min: 8, avg: 117.61, max: 343)
#
# Run: 143, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 119.52, max: 343)
#
# Run: 144, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 121.16, max: 343)
#
# Run: 145, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 122.9, max: 343)
#
# Run: 146, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 124.49, max: 343)
#
# Run: 147, exploration: 0.01, score: 229
# Scores: (min: 8, avg: 126.68, max: 343)
#
# Run: 148, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 128.5, max: 343)
#
# Run: 149, exploration: 0.01, score: 234
# Scores: (min: 8, avg: 130.69, max: 343)
#
# Run: 150, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 132.84, max: 343)
#
# Run: 151, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 134.93, max: 343)
#
# Run: 152, exploration: 0.01, score: 412
# Scores: (min: 8, avg: 138.94, max: 412)
#
# Run: 153, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 141.19, max: 412)
#
# Run: 154, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 143.49, max: 412)
#
# Run: 155, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 144.74, max: 412)
#
# Run: 156, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 146.81, max: 412)
#
# Run: 157, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 148.83, max: 412)
#
# Run: 158, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 150.81, max: 412)
#
# Run: 159, exploration: 0.01, score: 329
# Scores: (min: 9, avg: 154, max: 412)
#
# Run: 160, exploration: 0.01, score: 181
# Scores: (min: 9, avg: 155.7, max: 412)
#
# Run: 161, exploration: 0.01, score: 278
# Scores: (min: 9, avg: 158.34, max: 412)
#
# Run: 162, exploration: 0.01, score: 216
# Scores: (min: 9, avg: 160.38, max: 412)
#
# Run: 163, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 160.42, max: 412)
#
# Run: 164, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 160.38, max: 412)
#
# Run: 165, exploration: 0.01, score: 267
# Scores: (min: 9, avg: 162.95, max: 412)
#
# Run: 166, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 167.83, max: 500)
#
# Run: 167, exploration: 0.01, score: 234
# Scores: (min: 9, avg: 169.93, max: 500)
#
# Run: 168, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 169.95, max: 500)
#
# Run: 169, exploration: 0.01, score: 363
# Scores: (min: 9, avg: 173.4, max: 500)
#
# Run: 170, exploration: 0.01, score: 402
# Scores: (min: 9, avg: 177.32, max: 500)
#
# Run: 171, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 179.24, max: 500)
#
# Run: 172, exploration: 0.01, score: 312
# Scores: (min: 9, avg: 182.21, max: 500)
#
# Run: 173, exploration: 0.01, score: 204
# Scores: (min: 9, avg: 184.11, max: 500)
#
# Run: 174, exploration: 0.01, score: 217
# Scores: (min: 10, avg: 186.19, max: 500)
#
# Run: 175, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 187.95, max: 500)
#
# Run: 176, exploration: 0.01, score: 172
# Scores: (min: 10, avg: 189.57, max: 500)
#
# Run: 177, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 194.47, max: 500)
#
# Run: 178, exploration: 0.01, score: 205
# Scores: (min: 11, avg: 196.42, max: 500)
#
# Solved in 78 runs, 178 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-6-5d00f563e48c> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
# I originally tried setting gamma to 0.75 and 0.8 and I found that it was unable to complete, when I tried 0.9 I saw that it could solve it but it did take more runs to do so. Changing the learning rate to .005 was a much faster and completed it in significantly less runs. Changing the exploration variables to Max 0.9, Min 0.02, and Decay to 0.8 didn't show a lot of change and produced a very similar result to the original with 75 / 175 runs and this time 78 / 178. 

# The goal is to keep the cartpole balanced by applying appropriate forces to a pivot point. The different states are the condition of the cartpole or when it tilts to the side. Possible movements are to the left, right, or none. When the cart moves to the left the pole will tilt to the right, when the cart moves to the right then the cart tilts to the left. The reinforcement algorithm, Q learning, is used when it makes the right decisions then the pole will stay up and it gets rewarded. Reinforcement learning picks the best known action for any given state so we need to know which actions are better by assigning values to it. 

# Experience Replay is a replay memory technique used in reinforcement learning that solves the problem of autocorrelation leading to unstable training, by making the problem like a supervised learning problem. The discount factor determines the importance of future rewards. If it's lower then only current rewards are considered.

# By using a neural network, there are less memory requirements of continuous or bigger sets. The neural network is setup in a way so the inputs are states and ght output being pairs of actions and q values. The highest q value output will represent the best known actions for the current state. I noticed with a slight increase to the learning rate, it drastically reduced the amount of runs required to perfect its actions. 

# Surma, G. (2019, November 10). Cartpole - introduction to reinforcement learning (DQN - deep Q-learning). Medium. https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288 

# Papers with code - experience replay explained. Explained | Papers With Code. (n.d.). https://paperswithcode.com/method/experience-replay
